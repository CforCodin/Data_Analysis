# %% [markdown]
# <a href="https://colab.research.google.com/github/CforCodin/Data_Analysis/blob/main/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
df = pd.read_csv("data.csv")

# %%
print(os.listdir())
# Out:
# ['.config', 'data.csv', '.ipynb_checkpoints', 'sample_data']

# %%
df.head(10)
# Out:
#           Car       Model  Volume  Weight    CO2
# 0      Toyoty        Aygo  1000.0   790.0   99.0
# 1  Mitsubishi  Space Star  1200.0  1160.0   95.0
# 2       Skoda      Citigo  1000.0   929.0   95.0
# 3        Fiat         500   900.0   865.0   90.0
# 4        Mini      Cooper  1500.0  1140.0  105.0
# 5          VW         Up!  1000.0     NaN    NaN
# 6       Skoda         N/a  1400.0  1109.0   90.0
# 7    Mercedes     A-Class  1500.0  1365.0   92.0
# 8        Ford      Fiesta  1500.0  1112.0   98.0
# 9        Audi          A1  1600.0  1150.0   99.0

# %%
df.isna()
# Out:
#       Car  Model  Volume  Weight    CO2
# 0   False  False   False   False  False
# 1   False  False   False   False  False
# 2   False  False   False   False  False
# 3   False  False   False   False  False
# 4   False  False   False   False  False
# 5   False  False   False    True   True
# 6   False  False   False   False  False
# 7   False  False   False   False  False
# 8   False  False   False   False  False
# 9   False  False   False   False  False
# 10  False  False   False   False  False
# 11  False  False   False   False  False
# 12  False  False   False   False  False
# 13  False   True    True   False  False
# 14  False  False   False   False  False
# 15  False  False   False   False  False
# 16  False  False   False    True  False
# 17  False  False   False   False  False
# 18  False  False   False   False  False
# 19  False  False   False   False  False
# 20  False  False   False   False  False
# 21  False  False   False   False  False
# ...

# %%
df.isna().sum()
# Out:
# Car       0
# Model     2
# Volume    1
# Weight    2
# CO2       3
# dtype: int64

# %% [markdown]
# It does not consider n/a as Null so handling this problem

# %%
missing_value = ["N/a","n/a",np.nan]
df = pd.read_csv("data.csv", na_values = missing_value)

# %%
df.isnull().sum()
# Out:
# Car       0
# Model     4
# Volume    1
# Weight    2
# CO2       3
# dtype: int64

# %%
df.isnull().any()
# Out:
# Car       False
# Model      True
# Volume     True
# Weight     True
# CO2        True
# dtype: bool

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
df.dropna(how = "all")
# Out:
#            Car       Model  Volume  Weight    CO2
# 0       Toyoty        Aygo  1000.0   790.0   99.0
# 1   Mitsubishi  Space Star  1200.0  1160.0   95.0
# 2        Skoda      Citigo  1000.0   929.0   95.0
# 3         Fiat         500   900.0   865.0   90.0
# 4         Mini      Cooper  1500.0  1140.0  105.0
# 5           VW         Up!  1000.0     NaN    NaN
# 6        Skoda         NaN  1400.0  1109.0   90.0
# 7     Mercedes     A-Class  1500.0  1365.0   92.0
# 8         Ford      Fiesta  1500.0  1112.0   98.0
# 9         Audi          A1  1600.0  1150.0   99.0
# 10     Hyundai         NaN  1100.0   980.0   99.0
# 11      Suzuki       Swift  1300.0   990.0  101.0
# 12        Ford      Fiesta  1000.0  1112.0   99.0
# 13       Honda         NaN     NaN  1252.0   94.0
# 14      Hundai         I30  1600.0  1326.0   97.0
# 15        Opel       Astra  1600.0  1330.0   97.0
# 16         BMW           1  1600.0     NaN   99.0
# 17       Mazda           3  2200.0  1280.0  104.0
# ...

# %%
df1 = df.fillna(method = "bfill");

# %%
df1
# Out:
#            Car       Model  Volume  Weight    CO2
# 0       Toyoty        Aygo  1000.0   790.0   99.0
# 1   Mitsubishi  Space Star  1200.0  1160.0   95.0
# 2        Skoda      Citigo  1000.0   929.0   95.0
# 3         Fiat         500   900.0   865.0   90.0
# 4         Mini      Cooper  1500.0  1140.0  105.0
# 5           VW         Up!  1000.0     0.0    0.0
# 6        Skoda           0  1400.0  1109.0   90.0
# 7     Mercedes     A-Class  1500.0  1365.0   92.0
# 8         Ford      Fiesta  1500.0  1112.0   98.0
# 9         Audi          A1  1600.0  1150.0   99.0
# 10     Hyundai           0  1100.0   980.0   99.0
# 11      Suzuki       Swift  1300.0   990.0  101.0
# 12        Ford      Fiesta  1000.0  1112.0   99.0
# 13       Honda           0     0.0  1252.0   94.0
# 14      Hundai         I30  1600.0  1326.0   97.0
# 15        Opel       Astra  1600.0  1330.0   97.0
# 16         BMW           1  1600.0     0.0   99.0
# 17       Mazda           3  2200.0  1280.0  104.0
# ...

# %%
df.fillna(method = "ffill");
# Out:
#            Car       Model  Volume  Weight    CO2
# 0       Toyoty        Aygo  1000.0   790.0   99.0
# 1   Mitsubishi  Space Star  1200.0  1160.0   95.0
# 2        Skoda      Citigo  1000.0   929.0   95.0
# 3         Fiat         500   900.0   865.0   90.0
# 4         Mini      Cooper  1500.0  1140.0  105.0
# 5           VW         Up!  1000.0     0.0    0.0
# 6        Skoda           0  1400.0  1109.0   90.0
# 7     Mercedes     A-Class  1500.0  1365.0   92.0
# 8         Ford      Fiesta  1500.0  1112.0   98.0
# 9         Audi          A1  1600.0  1150.0   99.0
# 10     Hyundai           0  1100.0   980.0   99.0
# 11      Suzuki       Swift  1300.0   990.0  101.0
# 12        Ford      Fiesta  1000.0  1112.0   99.0
# 13       Honda           0     0.0  1252.0   94.0
# 14      Hundai         I30  1600.0  1326.0   97.0
# 15        Opel       Astra  1600.0  1330.0   97.0
# 16         BMW           1  1600.0     0.0   99.0
# 17       Mazda           3  2200.0  1280.0  104.0
# ...

# %%
df.interpolate()     #forward + backward/2
